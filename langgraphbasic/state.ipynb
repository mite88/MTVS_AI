# %%
! uv add langchain-core langchain-groq langgraph

# %%
from typing import TypedDict
from pydantic import BaseModel
from dataclasses import dataclass


class TypedDictState(TypedDict):
    query: str
    answer: str


class PyandticState(BaseModel):
    query: str
    answer: str

@dataclass
class DataClassstate:
    query: str
    answer: str

# %%
from langgraph.graph import StateGraph

# 1. TypedDict를 사용하는 경우
builder1 = StateGraph(TypedDictState)

# 2. Pydantic을 사용하는 경우
builder2 = StateGraph(PyandticState)

# 3. dataclass를 사용하는 경우
builder3 = StateGraph(DataClassstate)
