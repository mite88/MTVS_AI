# %% [markdown]
# ## Module
# `import` 다른 모듈을 현재 코드에서 사용 할 수 있도록 불러오는 구문
#
# ### **python 인터프린터가 import 만날때 순서**
# - 실행중인 스크립트의 디렉토리 탐색
# - PYTHONPATH 환경변수에 지정된 경로 탐색
# - 표준 라이브러리 경로 탐색
#
# 모듈을 한번 불러오면 이후 캐싱됨(sys.modules) -> 다른곳에 import 해도 재실행되지 않음

# %%
import math
import os
import sys

# %%
#math.sqrt()
#math.floor()

# %%
# !pip install -Uq pandas numpy

# %%
# 설치확인
import numpy as np
import pandas as pd

print(f"Pandas version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")

# Simple test
print(np.zeros(5))

df = pd.DataFrame({'a': [1, 2], 'b': [3, 4]})
print("\nDataFrame created successfully:")
print(df)
# Out:
# Pandas version: 2.5.0
# Pandas version: 3.0.3
# [0. 0. 0. 0. 0.]
#
# DataFrame created successfully:
#    a  b
# 0  1  3
# 1  2  4

# %% [markdown]
# ## from ... import ...
# - 모듈에서 특정명(클래스, 함수, 변수)만 선택적으로 불러오는 방식

# %%
from math import sqrt, pi, floor

print(sqrt(14))
print(pi)
# Out:
# 3.7416573867739413
# 3.141592653589793
